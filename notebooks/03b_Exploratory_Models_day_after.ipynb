# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

import stockutils

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.tree import export_graphviz
from graphviz import Source
from sklearn.ensemble import AdaBoostClassifier

from torch.utils.tensorboard import SummaryWriter

#track experiments
import wandb
from wandb.integration.xgboost import WandbCallback

# Where to save the figures
PROJECT_ROOT_DIR = ".."
CHAPTER_ID = "exploratory_models"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)
# Out:
# 2024-07-22 19:08:10.026152: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-22 19:08:10.026216: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-22 19:08:10.026755: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-22 19:08:10.032040: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
stockdf, targetdf, otherdf = stockutils.import_stock_csv("AAPL_Advanced.csv", target='DayAfterMajorReversal')
y_orig = targetdf["Target"]
print(y_orig.shape)
#targetdf.rename(columns={"DayAfterMajorReversal":'Target'}, inplace=True)
targetdf.head()
# Out:
# (2371,)
#           Target
# date
# 1/13/2015   HOLD
# 1/14/2015   HOLD
# 1/15/2015   HOLD
# 1/16/2015   HOLD
# 1/20/2015    BUY

# %%
# make sure we split train and test data with shuffle OFF
X_train, X_test, y_train, y_test = train_test_split(stockdf,y_orig, train_size=0.8,shuffle=False)
# other_test will be used later to help evaluate the efficacy of our predictions, by calculating a return on investment
other_test = otherdf.iloc[-y_test.shape[0]:]

#my stockutils does not remove the index, so...
#y_test.reset_index(drop=True, inplace=True)
#y_train.reset_index(drop=True, inplace=True)


#Problem is for cross validation splits, this won't work, so...

# use a TimeSeriesSplit to do cross validation
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits=10)

# %%
y_test.shape
# Out:
# (475,)

# %%
wandb.login(key=os.environ.get("WANDB_KEY"))
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: candrews1971 (christopherandrews). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Base ROI

# %%
import math
bah_actuals = pd.DataFrame(data=y_test, columns=["Target"], index=y_test.index.copy())
bah_actuals['close'] = other_test['close']
max_ROI = stockutils.calculate_total_gains_bhs(bah_actuals, init_value=1000, init_price=bah_actuals['close'][0])

num_bought = math.floor(1000/ bah_actuals['close'][0])
bah_ROI = (bah_actuals['close'][-1] - bah_actuals['close'][0])
# Out:
# Buying 6 shares for 151.60. Remaining Balance: 90.40000000000009
# Selling all shares for 174.15, cash balance: $1135.3000000000002
# Buying 7 shares for 142.99. Remaining Balance: 134.37000000000012
# Selling all shares for 153.34, cash balance: $1207.7500000000002
# Buying 8 shares for 146.87. Remaining Balance: 32.79000000000019
# Selling all shares for 148.01, cash balance: $1216.8700000000001
# Buying 9 shares for 129.62. Remaining Balance: 50.29000000000019
# Selling all shares for 153.71, cash balance: $1433.6800000000003
# Buying 9 shares for 145.91. Remaining Balance: 120.49000000000024
# Selling all shares for 195.60, cash balance: $1880.9350000000002
# Buying 10 shares for 174.49. Remaining Balance: 136.03500000000008
# Selling all shares for 182.91, cash balance: $1965.135
# Buying 11 shares for 173.75. Remaining Balance: 53.88499999999999
# Selling all shares for 178.85, cash balance: $2021.235
# Buying 12 shares for 168.22. Remaining Balance: 2.5950000000000273
# Selling all shares for 197.57, cash balance: $2373.4350000000004
# Buying 12 shares for 188.63. Remaining Balance: 109.87500000000045
# Selling all shares for 194.50, cash balance: $2443.8750000000005
# Buying 14 shares for 165.84. Remaining Balance: 122.11500000000024
# Selling all remaining held shares, cash balance: $3121.4750000000004 ***********************

# %% [markdown]
# # Decision Tree Classifier

# %%
#wandb.init(entity="christopherandrews", project="StockPredictor", name="DecisionTreeClassifier_v01", save_code=False)

# %%
y_test.head()
# Out:
# date
# 7/26/2022    BUY
# 7/27/2022    BUY
# 7/28/2022    BUY
# 7/29/2022    BUY
# 8/1/2022     BUY
# Name: Target, dtype: category
# Categories (3, object): ['BUY', 'HOLD', 'SELL']

# %%
# Create the DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=2, random_state=2)

#set up for a Grid Search 
dtc_param_grid = {'max_depth':[1,2,3,4,5,6,7], 
                  'min_samples_split': [2,4,8,16,32,64], 
                  'min_samples_leaf': [2,4,8,16,32,64]}

#log to weights and biases
run_name = f"DecisionTreeClassifier_shuffled_{int(time.time())}"
run = wandb.init(entity="christopherandrews", project="StockPredictor", name=run_name, save_code=False, settings=wandb.Settings(start_method="fork"), reinit=True)

#Perform the training with a grid search
dtc_gs = GridSearchCV(dt, param_grid=dtc_param_grid, cv=tscv, scoring='accuracy', verbose=True)
dtc_gs.fit(X_train, y_train)

y_pred = dtc_gs.predict(X_test) #uses best estimator

#log accuracy score
run.summary['accuracy'] = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy_score(y_test, y_pred))

# calculate ROI, need a dataframe with predicted 'Target' and actual 'close'
dtc_preds = pd.DataFrame(data=y_pred, columns=["Target"], index=y_test.index.copy())
dtc_preds['close'] = other_test['close']
run.summary["ROI"] = stockutils.calculate_total_gains_bhs(dtc_preds, init_value=1000, init_price=dtc_preds['close'][0])
run.summary["Buy And Hold (Base ROI)"] = bah_ROI
run.summary["Max ROI"] = max_ROI

wandb.sklearn.plot_confusion_matrix(y_test, y_pred, ["BUY", "HOLD", "SELL"])

run.finish()
# Out:
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/home/candrews/Projects/MyProjects/StockPredictor/notebooks/wandb/run-20240722_190813-slezp878</code>
# Syncing run <strong><a href='https://wandb.ai/christopherandrews/StockPredictor/runs/slezp878' target="_blank">DecisionTreeClassifier_shuffled_1721696893</a></strong> to <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a>
#  View run at <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/slezp878' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/slezp878</a>
# Fitting 10 folds for each of 252 candidates, totalling 2520 fits
# Accuracy:  0.52
# Buying 6 shares for 151.60. Remaining Balance: 90.40000000000009
# Selling all shares for 161.38, cash balance: $1058.68
# Buying 6 shares for 163.43. Remaining Balance: 78.10000000000002
# Selling all shares for 150.77, cash balance: $982.7200000000001
# Buying 6 shares for 142.41. Remaining Balance: 128.2600000000001
# Selling all shares for 138.38, cash balance: $958.5400000000001
# Buying 6 shares for 150.04. Remaining Balance: 58.30000000000007
# Selling all shares for 140.94, cash balance: $903.94
# Buying 6 shares for 133.49. Remaining Balance: 103.0
# Selling all shares for 145.31, cash balance: $974.86
# Buying 6 shares for 153.83. Remaining Balance: 51.879999999999995
# Selling all shares for 181.99, cash balance: $1143.8200000000002
# Buying 6 shares for 181.12. Remaining Balance: 57.100000000000136
# Selling all shares for 174.21, cash balance: $1102.3600000000001
# Buying 6 shares for 174.91. Remaining Balance: 52.90000000000009
# Selling all shares for 166.89, cash balance: $1054.24
# Buying 5 shares for 177.57. Remaining Balance: 166.3900000000001
# Selling all shares for 185.64, cash balance: $1094.5900000000001
# Buying 5 shares for 188.63. Remaining Balance: 151.44000000000017
# Selling all shares for 170.12, cash balance: $1002.0400000000002
# Buying 5 shares for 173.72. Remaining Balance: 133.44000000000017
# Selling all shares for 168.82, cash balance: $977.5400000000001
# Buying 5 shares for 175.04. Remaining Balance: 102.34000000000015
# Selling all remaining held shares, cash balance: $1173.5400000000002 ***********************
# VBox(children=(Label(value='0.003 MB of 0.003 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Buy And Hold (Base ROI)</td><td>62.64</td></tr><tr><td>Max ROI</td><td>2121.475</td></tr><tr><td>ROI</td><td>173.54</td></tr><tr><td>accuracy</td><td>0.52</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DecisionTreeClassifier_shuffled_1721696893</strong> at: <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/slezp878' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/slezp878</a><br/> View project at: <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a><br/>Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240722_190813-slezp878/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
#In case the above fails
#run.finish()

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d")
# Out:
# <Axes: >

# %% [markdown]
# Hold seems to be a problem...

# %%
logged_config = dtc_gs.best_params_
logged_config["Model"] = "DecisionTreeClassifier"

# %% [markdown]
# 56% accuracy, hmmm...  that's hardly better than just a guess!

# %%
# Get the best paramters from the model
dtc_gs.best_params_
# Out:
# {'max_depth': 2,
#  'min_samples_leaf': 2,
#  'min_samples_split': 64,
#  'Model': 'DecisionTreeClassifier'}

# %%
outputfilepath = os.path.join(IMAGES_PATH, "GridSearchDTC.dot")
export_graphviz(dtc_gs.best_estimator_, out_file=outputfilepath, feature_names=X_train.columns, class_names=["BUY","HOLD",'SELL'], rounded=True, filled=True )

# %%
Source.from_file(outputfilepath)

# %%
feature_importances = list(zip(X_train.columns, dtc_gs.best_estimator_.feature_importances_))
fi = pd.Series(dtc_gs.best_estimator_.feature_importances_, index=X_train.columns)
sorted_imp = pd.DataFrame(fi.sort_values(ascending=True), columns=['importance'])
sorted_imp.plot(kind='barh',color="red")
# Out:
# <Axes: >

# %% [markdown]
# It only seems to want to use the 6 and 10 day SMA slope...

# %% [markdown]
# # AdaBoost Classifier

# %%
adb_param_grid = {"learning_rate":[0.001, 0.01, 0.1],
                  'n_estimators':[50, 100, 200] }

#log to weights and biases
run_name = f"AdaBoostClassifier_shuffled_{int(time.time())}"
run = wandb.init(entity="christopherandrews", project="StockPredictor", name=run_name, save_code=False, settings=wandb.Settings(start_method="fork"), reinit=True)

adb_clf = AdaBoostClassifier(estimator=dt, algorithm='SAMME', n_estimators=200, random_state=42)

adb_gs = GridSearchCV(adb_clf, param_grid=adb_param_grid, cv=tscv, scoring='accuracy', verbose=True)

adb_gs.fit(X_train, y_train)

y_pred = adb_gs.predict(X_test) #uses best estimator

run.summary['accuracy'] = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy_score(y_test, y_pred))


# calculate ROI, need a dataframe with predicted 'Target' and actual 'close'
adb_preds = pd.DataFrame(data=y_pred, columns=["Target"], index=y_test.index.copy())
adb_preds['close'] = other_test['close']
run.summary["ROI"] = stockutils.calculate_total_gains_bhs(adb_preds, init_value=1000, init_price=adb_preds['close'][0])
run.summary["Buy And Hold (Base ROI)"] = bah_ROI
run.summary["Max ROI"] = max_ROI

wandb.sklearn.plot_confusion_matrix(y_test, y_pred, ["BUY", "HOLD", "SELL"])

run.finish()
# Out:
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/home/candrews/Projects/MyProjects/StockPredictor/notebooks/wandb/run-20240722_190908-6kb7ti1l</code>
# Syncing run <strong><a href='https://wandb.ai/christopherandrews/StockPredictor/runs/6kb7ti1l' target="_blank">AdaBoostClassifier_shuffled_1721696948</a></strong> to <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a>
#  View run at <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/6kb7ti1l' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/6kb7ti1l</a>
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# Accuracy:  0.6421052631578947
# Buying 6 shares for 151.60. Remaining Balance: 90.40000000000009
# Selling all shares for 163.62, cash balance: $1072.1200000000001
# Buying 6 shares for 163.43. Remaining Balance: 91.54000000000008
# Selling all shares for 153.84, cash balance: $1014.58
# Buying 6 shares for 156.90. Remaining Balance: 73.17999999999995
# Selling all shares for 150.43, cash balance: $975.76
# Buying 6 shares for 142.99. Remaining Balance: 117.81999999999994
# Selling all shares for 138.88, cash balance: $951.0999999999999
# Buying 6 shares for 146.87. Remaining Balance: 69.87999999999988
# Selling all shares for 149.70, cash balance: $968.0799999999998
# Buying 6 shares for 150.04. Remaining Balance: 67.8399999999998
# Selling all shares for 144.22, cash balance: $933.1599999999997
# Buying 6 shares for 148.31. Remaining Balance: 43.29999999999973
# Selling all shares for 142.91, cash balance: $900.7599999999998
# Buying 6 shares for 144.49. Remaining Balance: 33.81999999999971
# Selling all shares for 136.50, cash balance: $852.8199999999997
# Buying 6 shares for 130.73. Remaining Balance: 68.43999999999983
# Selling all shares for 148.91, cash balance: $961.8999999999999
# Buying 6 shares for 153.83. Remaining Balance: 38.919999999999845
# Selling all shares for 181.99, cash balance: $1130.86
# Buying 6 shares for 181.12. Remaining Balance: 44.13999999999987
# Selling all shares for 177.56, cash balance: $1109.5
# Buying 6 shares for 173.66. Remaining Balance: 67.53999999999996
# Selling all shares for 172.88, cash balance: $1104.82
# Buying 6 shares for 173.97. Remaining Balance: 61.0
# Selling all shares for 185.64, cash balance: $1174.84
# Buying 6 shares for 188.63. Remaining Balance: 43.059999999999945
# Selling all shares for 185.85, cash balance: $1158.1599999999999
# Buying 6 shares for 173.72. Remaining Balance: 115.83999999999992
# Selling all shares for 168.82, cash balance: $1128.7599999999998
# Buying 6 shares for 169.67. Remaining Balance: 110.73999999999978
# Selling all shares for 165.00, cash balance: $1100.7399999999998
# Buying 6 shares for 169.02. Remaining Balance: 86.61999999999966
# Selling all remaining held shares, cash balance: $1372.0599999999997 ***********************
# VBox(children=(Label(value='0.016 MB of 0.016 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Buy And Hold (Base ROI)</td><td>62.64</td></tr><tr><td>Max ROI</td><td>2121.475</td></tr><tr><td>ROI</td><td>372.06</td></tr><tr><td>accuracy</td><td>0.64211</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AdaBoostClassifier_shuffled_1721696948</strong> at: <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/6kb7ti1l' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/6kb7ti1l</a><br/> View project at: <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a><br/>Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240722_190908-6kb7ti1l/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d")
# Out:
# <Axes: >

# %%
feature_importances = list(zip(X_train.columns, adb_gs.best_estimator_.feature_importances_))
fi = pd.Series(adb_gs.best_estimator_.feature_importances_, index=X_train.columns)
sorted_imp = pd.DataFrame(fi.sort_values(ascending=True), columns=['importance'])
sorted_imp.plot(kind='barh',color="red")
# Out:
# <Axes: >

# %% [markdown]
# We end up using a few more features, and get a fairly surprising 64% accuracy.

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# adb_param_grid = {"learning_rate":[0.001, 0.01, 0.1],
#                   'n_estimators':[50, 100, 200] }

#log to weights and biases
run_name = f"GradientBoostClassifier_shuffled_{int(time.time())}"
run = wandb.init(entity="christopherandrews", project="StockPredictor", name=run_name, save_code=False, settings=wandb.Settings(start_method="fork"), reinit=True)


#Use a time series split as the CV
tscv = TimeSeriesSplit(n_splits=8)

gbc = GradientBoostingClassifier(max_depth=2, random_state=42, loss='log_loss')

gbc_params = {'learning_rate':[0.001], 'n_estimators':[ 800]}

#RandomizedSearchCV
gbc_gs = GridSearchCV(gbc, param_grid=gbc_params, cv=tscv, scoring='accuracy', verbose=True)

gbc_gs.fit(X_train, y_train)


y_pred = gbc_gs.predict(X_test) #uses best estimator
#y_probas = gbc_gs.predict_proba(X_test)

run.summary['accuracy'] = accuracy_score(y_test, y_pred)
#run.summary['precision'] = precision_score(y_test, y_pred)
#run.summary['recall'] = recall_score(y_test, y_pred)

# calculate ROI, need a dataframe with predicted 'Target' and actual 'close'
gbc_preds = pd.DataFrame(data=y_pred, columns=["Target"], index=y_test.index.copy())
gbc_preds['close'] = other_test['close']
run.summary["ROI"] = stockutils.calculate_total_gains_bhs(gbc_preds, init_value=1000, init_price=gbc_preds['close'][0])
run.summary["Buy And Hold (Base ROI)"] = bah_ROI
run.summary["Max ROI"] = max_ROI

print("Accuracy: ", accuracy_score(y_test, y_pred))
#wandb.sklearn.plot_roc(y_test, y_probas, ["BUY", "HOLD", "SELL"])
wandb.sklearn.plot_confusion_matrix(y_test, y_pred, ["BUY", "HOLD", "SELL"])
#wandb.sklearn.plot_learning_curve(gbc_gs.best_estimator_, X_train, y_train)
run.finish()
# Out:
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/home/candrews/Projects/MyProjects/StockPredictor/notebooks/wandb/run-20240722
# Buying 5 shares for 182.32. Remaining Balance: 135.83999999999946
# Selling all shares for 181.16, cash balance: $1041.6399999999994
# Buying 5 shares for 182.63. Remaining Balance: 128.48999999999944
# Selling all shares for 175.10, cash balance: $1003.9899999999994
# Buying 5 shares for 173.00. Remaining Balance: 138.98999999999944
# Selling all shares for 168.82, cash balance: $983.0899999999993
# Buying 5 shares for 169.58. Remaining Balance: 135.18999999999926
# Selling all shares for 165.00, cash balance: $960.1899999999993
# Buying 5 shares for 166.90. Remaining Balance: 125.68999999999926
# Selling all remaining held shares, cash balance: $1196.8899999999994 ***********************
# Accuracy:  0.6968421052631579
# VBox(children=(Label(value='0.003 MB of 0.003 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Buy And Hold (Base ROI)</td><td>62.64</td></tr><tr><td>Max ROI</td><td>2121.475</td></tr><tr><td>ROI</td><td>196.89</td></tr><tr><td>accuracy</td><td>0.69684</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GradientBoostClassifier_shuffled_1721697047</strong> at: <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/750flz5z' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/750flz5z</a><br/> View project at: <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a><br/>Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240722_191047-750flz5z/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %% [markdown]
# This is quite slow compared to XGBoost

# %%
run.finish()

# %%
gbc_gs.best_params_
# Out:
# {'learning_rate': 0.001, 'n_estimators': 800}

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d")
# Out:
# <Axes: >

# %%
stockutils.plot_feature_importances(X_train=X_train, estimator=gbc_gs.best_estimator_)

# %% [markdown]
# BUT, it always predicts a buy or sell, never hold!

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#log to weights and biases
run_name = f"RandomForestClassifier_shuffled_{int(time.time())}"
run = wandb.init(entity="christopherandrews", 
                project="StockPredictor", 
                name=run_name, save_code=False, 
                settings=wandb.Settings(start_method="fork"), 
                reinit=True, 
                sync_tensorboard=True,)

#tscv = TimeSeriesSplit(n_splits=8)
tscv = 10

#cls = StackingClassifier(max_depth=2, random_state=42, loss='log_loss')
cls = RandomForestClassifier(random_state=42)

#Base classifier 
cls.fit(X_train, y_train)
y_pred = cls.predict(X_test)

print("Base classifier accuracy:", accuracy_score(y_test, y_pred))


#gbc_params = {'learning_rate':[0.001, 0.01, 0.1, 1, 10], 'n_estimators':[100,200,300]}
cls_params = {'max_depth':[2, 4, 6], 'n_estimators':[100, 200, 400, 800, 1000], 'max_features': [2, 4, 6 ]}

rf_gs = RandomizedSearchCV(cls, param_distributions=cls_params, cv=tscv, scoring='accuracy', verbose=True)

rf_gs.fit(X_train, y_train)

y_pred = rf_gs.predict(X_test) #uses best estimator
#y_probas = gbc_gs.predict_proba(X_test)

run.summary['accuracy'] = accuracy_score(y_test, y_pred)
#run.summary['precision'] = precision_score(y_test, y_pred)
#run.summary['recall'] = recall_score(y_test, y_pred)
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text("hyperparameters",
                "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in rf_gs.best_params_.items()]))
)

# calculate ROI, need a dataframe with predicted 'Target' and actual 'close'
rf_preds = pd.DataFrame(data=y_pred, columns=["Target"], index=y_test.index.copy())
rf_preds['close'] = other_test['close']
run.summary["ROI"] = stockutils.calculate_total_gains_bhs(rf_preds, init_value=1000, init_price=rf_preds['close'][0])
run.summary["Buy And Hold (Base ROI)"] = bah_ROI
run.summary["Max ROI"] = max_ROI

print("Accuracy: ", accuracy_score(y_test, y_pred))
wandb.sklearn.plot_confusion_matrix(y_test, y_pred, ["BUY", "HOLD", "SELL"])

run.finish()
# Out:
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/home/candrews/Projects/MyProjects/StockPredictor/notebooks/wandb/run-20240722_191320-zl24xwq5</code>
# Syncing run <strong><a href='https://wandb.ai/christopherandrews/StockPredictor/runs/zl24xwq5' target="_blank">RandomForestClassifier_shuffled_1721697200</a></strong> to <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a>
#  View run at <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/zl24xwq5' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/zl24xwq5</a>
# Base classifier accuracy: 0.5852631578947368
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Buying 6 shares for 151.60. Remaining Balance: 90.40000000000009
# Selling all shares for 167.23, cash balance: $1093.78
# Buying 6 shares for 157.37. Remaining Balance: 149.55999999999995
# Selling all shares for 153.84, cash balance: $1072.6
# Buying 6 shares for 156.90. Remaining Balance: 131.19999999999982
# Selling all shares for 150.43, cash balance: $1033.7799999999997
# Buying 7 shares for 142.99. Remaining Balance: 32.84999999999968
# Selling all shares for 138.38, cash balance: $1001.5099999999996
# Buying 7 shares for 142.41. Remaining Balance: 4.639999999999645
# Selling all shares for 138.88, cash balance: $976.7999999999996
# Buying 6 shares for 146.87. Remaining Balance: 95.57999999999959
# Selling all shares for 144.22, cash balance: $960.8999999999995
# Buying 6 shares for 148.31. Remaining Balance: 71.03999999999951
# Selling all shares for 142.91, cash balance: $928.4999999999995
# Buying 6 shares for 144.49. Remaining Balance: 61.55999999999949
# Selling all shares for 136.50, cash balance: $880.5599999999995
# Buying 6 shares for 129.62. Remaining Balance: 102.83999999999946
# Selling all shares for 148.48, cash balance: $993.7199999999993
# Buying 6 shares for 151.03. Remaining Balance: 87.53999999999928
# Selling all shares for 181.99, cash balance: $1179.4799999999993
# Buying 6 shares for 181.12. Remaining Balance: 92.75999999999931
# Selling all shares for 177.56, cash balance: $1158.1199999999994
# Buying 6 shares for 173.66. Remaining Balance: 116.1599999999994
# Selling all shares for 172.88, cash balance: $1153.4399999999994
# Buying 6 shares for 173.97. Remaining Balance: 109.61999999999944
# Selling all shares for 185.64, cash balance: $1223.4599999999994
# Buying 6 shares for 186.19. Remaining Balance: 106.31999999999948
# Selling all shares for 183.63, cash balance: $1208.0999999999995
# Buying 6 shares for 188.63. Remaining Balance: 76.31999999999948
# Selling all shares for 184.40, cash balance: $1182.7199999999996
# Buying 6 shares for 189.41. Remaining Balance: 46.259999999999536
# Selling all shares for 185.04, cash balance: $1156.4999999999995
# Buying 6 shares for 173.23. Remaining Balance: 117.11999999999966
# Selling all shares for 169.71, cash balance: $1135.3799999999997
# Buying 6 shares for 173.31. Remaining Balance: 95.51999999999953
# Selling all shares for 168.82, cash balance: $1108.4399999999996
# Buying 6 shares for 175.04. Remaining Balance: 58.19999999999959
# Selling all shares for 168.00, cash balance: $1066.1999999999996
# Buying 6 shares for 169.02. Remaining Balance: 52.07999999999947
# Selling all remaining held shares, cash balance: $1337.5199999999995 ***********************
# Accuracy:  0.6694736842105263
# 2024-07-22 19:16:16.975425: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-22 19:16:16.975485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-22 19:16:16.976067: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-22 19:16:16.982125: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# VBox(children=(Label(value='0.003 MB of 0.003 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Buy And Hold (Base ROI)</td><td>62.64</td></tr><tr><td>Max ROI</td><td>2121.475</td></tr><tr><td>ROI</td><td>337.52</td></tr><tr><td>accuracy</td><td>0.66947</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RandomForestClassifier_shuffled_1721697200</strong> at: <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/zl24xwq5' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/zl24xwq5</a><br/> View project at: <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a><br/>Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240722_191320-zl24xwq5/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
wandb.finish()

# %%
rf_gs.best_params_
# Out:
# {'n_estimators': 1000, 'max_features': 6, 'max_depth': 2}

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d")
# Out:
# <Axes: >

# %%
stockutils.plot_feature_importances(X_train=X_train, estimator=rf_gs.best_estimator_)

# %% [markdown]
# # PCA
# Out of curiosity, what does affect does running PCA on the data prior to training end up with?

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn import set_config
from sklearn.preprocessing import StandardScaler

# yay! this is nice!  now our transform creates a pandas dataframe instead of numpy array
set_config(transform_output="pandas")

pca_scaler = StandardScaler()
pca = PCA(n_components=5)

pipeline = make_pipeline(pca_scaler, pca)

pipeline.fit(X_train)
pca.get_feature_names_out(input_features=X_train.columns)
# Out:
# array(['pca0', 'pca1', 'pca2', 'pca3', 'pca4'], dtype=object)

# %%
transformed = pca.transform(X_train)
print(transformed.shape)
# Out:
# (1896, 5)

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xticks(features)
plt.ylabel('variance')
plt.xlabel('PCA_ feature')
plt.show()

# %%
#rf_gs.fit(transformed, y_train)

#y_pred = rf_gs.predict(pca.transform(X_test))

# %%
#print("Accuracy: ", accuracy_score(y_test, y_pred))

# %% [markdown]
# 30%, hmm... that's pretty bad

# %% [markdown]
# # XGBoost

# %%
#y_train_xgb = pd.Categorical(y_train['Target']).codes
y_train_xgb = pd.Categorical(y_train).codes

#y_test_xgb = pd.Categorical(y_test['Target']).codes
y_test_xgb = pd.Categorical(y_test).codes

# %%
import xgboost as xgb

#log to weights and biases
run_name = f"XGBoostClassifier_shuffled_{int(time.time())}"
run = wandb.init(entity="christopherandrews", 
                project="StockPredictor", 
                name=run_name, save_code=False, 
                settings=wandb.Settings(start_method="fork"), 
                reinit=True, 
                sync_tensorboard=True,)

tscv = 10

evals = [(X_train, y_train_xgb), (X_test, y_test_xgb)]



cls = xgb.XGBClassifier(objective='multi:softmax', 
                        num_class=3,
                        n_estimators=500, 
                        seed=42, 
                        importance_type='gain', 
                        device="cuda",
                        early_stopping_rounds=20,
                        eval_metric=['merror', 'mlogloss'],
                        callbacks=[WandbCallback(log_feature_importance=True, importance_type="gain")]
                        ) 
#Base classifier 
cls.fit(X_train, y_train_xgb, eval_set=evals)
y_pred_train_xgb = cls.predict(X_train)
y_pred_test_xgb = cls.predict(X_test)

print("Base classifier training set accuracy:", accuracy_score(y_train_xgb, y_pred_train_xgb))
print("Base classifier test set accuracy:", accuracy_score(y_test_xgb, y_pred_test_xgb))
print("Base classifier params:", cls.get_params())

# alpha is L1 regularization - zeros some weights
#lambda is L2 regularization - smoother penalty
# cls_params = {
#     'learning_rate':[0.001,0.01, 0.1, 0.2, 1, 10],
#     'max_depth':[1,2],
#     'subsample':[ 0.2, 0.5, 0.7, 0.8, 0.9]
# }

cls_params = {
    'n_estimators': [50, 100, 250, 500],
    'learning_rate':[0.001, 0.01, 0.1],
    'max_depth':[2, 4, 6],
    'subsample':[ 0.1, 0.2]
}
xgb_gs = RandomizedSearchCV(cls, param_distributions=cls_params, cv=tscv, scoring='accuracy', verbose=False)

#xgb_gs = GridSearchCV(cls, param_grid=cls_params, cv=tscv, scoring='accuracy', verbose=False)

xgb_gs.fit(X_train, y_train_xgb, eval_set=evals)

y_pred = xgb_gs.predict(X_test)

run.summary['accuracy'] = accuracy_score(y_test_xgb, y_pred)


# calculate ROI, need a dataframe with predicted 'Target' and actual 'close'
xgb_preds = pd.DataFrame(data=y_pred, columns=["Target"], index=y_test.index.copy())
xgb_preds['close'] = other_test['close']
run.summary["ROI"] = stockutils.calculate_total_gains_bhs(xgb_preds, init_value=1000, init_price=xgb_preds['close'][0])
run.summary["Buy And Hold (Base ROI)"] = bah_ROI
run.summary["Max ROI"] = max_ROI

print("Test Accuracy: ", accuracy_score(y_test_xgb, y_pred))
print("Best Params", xgb_gs.best_params_)

wandb.sklearn.plot_confusion_matrix(y_test_xgb, y_pred)

run.finish()
# Out:
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/home/candrews/Projects/MyProjects/StockPredictor/notebooks/wandb/run-20240722_191630-vy1gawj8</code>
# Syncing run <strong><a href='https://wandb.ai/christopherandrews/StockPredictor/runs/vy1gawj8' target="_blank">XGBoostClassifier_shuffled_1721697390</a></strong> to <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a>
#  View run at <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/vy1gawj8' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/vy1gawj8</a>
# [0]	validation_0-merror:0.15823	validation_0-mlogloss:0.87087	validation_1-merror:0.47158	validation_1-mlogloss:1.01990
# [1]	validation_0-merror:0.12922	validation_0-mlogloss:0.72751	validation_1-merror:0.48000	validation_1-mlogloss:0.98377
# [2]	validation_0-merror:0.10812	validation_0-mlogloss:0.61776	validation_1-merror:0.42316	validation_1-mlogloss:0.94281
# [3]	validation_0-merror:0.09705	validation_0-mlogloss:0.53717	validation_1-merror:0.42105	validation_1-mlogloss:0.91199
# [4]	validation_0-merror:0.08122	validation_0-mlogloss:0.47024	validation_1-merror:0.45053	validation_1-mlogloss:0.92363
# [5]	validation_0-merror:0.07278	validation_0-mlogloss:0.42373	validation_1-merror:0.42316	validation_1-mlogloss:0.89782
# [6]	validation_0-merror:0.06276	validation_0-mlogloss:0.37870	validation_1-merror:0.42947	validation_1-mlogloss:0.89823
# [7]	validation_0-merror:0.05696	validation_0-mlogloss:0.34399	validation_1-merror:0.42316	validation_1-mlogloss:0.89759
# [8]	validation_0-merror:0.04958	validation_0-mlogloss:0.31318	validation_1-merror:0.41474	validation_1-mlogloss:0.90841
# [9]	validation_0-merror:0.04378	validation_0-mlogloss:0.28474	validation_1-merror:0.40000	validation_1-mlogloss:0.89019
# [10]	validation_0-merror:0.04167	validation_0-mlogloss:0.26677	validation_1-merror:0.41474	validation_1-mlogloss:0.90439
# [11]	validation_0-merror:0.03112	validation_0-mlogloss:0.24288	validation_1-merror:0.42947	validation_1-mlogloss:0.90868
# [12]	validation_0-merror:0.02901	validation_0-mlogloss:0.22311	validation_1-merror:0.41684	validation_1-mlogloss:0.91133
# [13]	validation_0-merror:0.02373	validation_0-mlogloss:0.20589	validation_1-merror:0.42105	validation_1-mlogloss:0.92421
# [14]	validation_0-merror:0.02268	validation_0-mlogloss:0.19670	validation_1-merror:0.43789	validation_1-mlogloss:0.93819
# [15]	validation_0-merror:0.01846	validation_0-mlogloss:0.18607	validation_1-merror:0.42737	validation_1-mlogloss:0.93484
# [16]	validation_0-merror:0.01582	validation_0-mlogloss:0.17602	validation_1-merror:0.42105	validation_1-mlogloss:0.93283
# [17]	validation_0-merror:0.01319	validation_0-mlogloss:0.16605	validation_1-merror:0.42316	validation_1-mlogloss:0.94251
# [18]	validation_0-merror:0.01160	validation_0-mlogloss:0.15756	validation_1-merror:0.43368	validation_1-mlogloss:0.96962
# [19]	validation_0-merror:0.01108	validation_0-mlogloss:0.14657	validation_1-merror:0.44000	validation_1-mlogloss:0.99013
# [20]	validation_0-merror:0.01002	validation_0-mlogloss:0.14072	validation_1-merror:0.44211	validation_1-mlogloss:1.01160
# [21]	validation_0-merror:0.00897	validation_0-mlogloss:0.13281	validation_1-merror:0.44421	validation_1-mlogloss:1.00835
# [22]	validation_0-merror:0.00686	validation_0-mlogloss:0.12461	validation_1-merror:0.44421	validation_1-mlogloss:1.03037
# [23]	validation_0-merror:0.00686	validation_0-mlogloss:0.11944	validation_1-merror:0.44211	validation_1-mlogloss:1.03131
# [24]	validation_0-merror:0.00580	validation_0-mlogloss:0.11031	validation_1-merror:0.42947	validation_1-mlogloss:1.00693
# [25]	validation_0-merror:0.00527	validation_0-mlogloss:0.10427	validation_1-merror:0.42737	validation_1-mlogloss:1.00275
# [26]	validation_0-merror:0.00316	validation_0-mlogloss:0.09842	validation_1-merror:0.42526	validation_1-mlogloss:1.02408
# [27]	validation_0-merror:0.00316	validation_0-mlogloss:0.09395	validation_1-merror:0.42947	validation_1-mlogloss:1.03369
# [28]	validation_0-merror:0.00158	validation_0-mlogloss:0.08877	validation_1-merror:0.41474	validation_1-mlogloss:1.02068
# [29]	validation_0-merror:0.00211	validation_0-mlogloss:0.08521	validation_1-merror:0.42316	validation_1-mlogloss:1.03146
# /home/candrews/anaconda3/envs/cuml/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [19:16:47] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1706051839871/work/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# Base classifier training set accuracy: 0.9562236286919831
# Base classifier test set accuracy: 0.6
# Base classifier params: {'objective': 'multi:softmax', 'base_score': None, 'booster': None, 'callbacks': [<wandb.integration.xgboost.xgboost.WandbCallback object at 0x7f9d12cc4460>], 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': 'cuda', 'early_stopping_rounds': 20, 'enable_categorical': False, 'eval_metric': ['merror', 'mlogloss'], 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': 'gain', 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 500, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'num_class': 3, 'seed': 42}
# [0]	validation_0-merror:0.31857	validation_0-mlogloss:1.09254	validation_1-merror:0.47368	validation_1-mlogloss:1.09558
# [1]	validation_0-merror:0.27162	validation_0-mlogloss:1.08650	validation_1-merror:0.36632	validation_1-mlogloss:1.09109
# [2]	validation_0-merror:0.25633	validation_0-mlogloss:1.08031	validation_1-merror:0.37684	validation_1-mlogloss:1.08805
# [3]	validation_0-merror:0.23576	validation_0-mlogloss:1.07397	validation_1-merror:0.36000	validation_1-mlogloss:1.08291
# [4]	validation_0-merror:0.22627	validation_0-mlogloss:1.06808	validation_1-merror:0.34526	validation_1-mlogloss:1.07823
# [5]	validation_0-merror:0.22152	validation_0-mlogloss:1.06249	validation_1-merror:0.38737	validation_1-mlogloss:1.07674
# [6]	validation_0-merror:0.21730	validation_0-mlogloss:1.05661	validation_1-merror:0.37895	validation_1-mlogloss:1.07294
# [7]	validation_0-merror:0.21466	validation_0-mlogloss:1.05090	validation_1-merror:0.36000	validation_1-mlogloss:1.06877
# [8]	validation_0-merror:0.21097	validation_0-mlogloss:1.04576	validation_1-merror:0.32842	validation_1-mlogloss:1.06441
# [9]	validation_0-merror:0.21361	validation_0-mlogloss:1.04007	validation_1-merror:0.32000	validation_1-mlogloss:1.05938
# [10]	validation_0-merror:0.21519	validation_0-mlogloss:1.03484	validation_1-merror:0.32421	validation_1-mlogloss:1.05548
# [11]	validation_0-merror:0.21466	validation_0-mlogloss:1.02943	validation_1-merror:0.30105	validation_1-mlogloss:1.05007
# [12]	validation_0-merror:0.21414	validation_0-mlogloss:1.02382	validation_1-merror:0.30737	validation_1-mlogloss:1.04580
# [13]	validation_0-merror:0.21255	validation_0-mlogloss:1.01853	validation_1-merror:0.30105	validation_1-mlogloss:1.04171
# [14]	validation_0-merror:0.21466	validation_0-mlogloss:1.01314	validation_1-merror:0.30526	validation_1-mlogloss:1.03808
# [15]	validation_0-merror:0.21308	validation_0-mlogloss:1.00786	validation_1-merror:0.30947	validation_1-mlogloss:1.03425
# [16]	validation_0-merror:0.21308	validation_0-mlogloss:1.00262	validation_1-merror:0.29895	validation_1-mlogloss:1.03065
# [17]	validation_0-merror:0.21255	validation_0-mlogloss:0.99743	validation_1-merror:0.31368	validation_1-mlogloss:1.02733
# [18]	validation_0-merror:0.20464	validation_0-mlogloss:0.99198	validation_1-merror:0.30737	validation_1-mlogloss:1.02413
# [19]	validation_0-merror:0.20781	validation_0-mlogloss:0.98694	validation_1-merror:0.30947	validation_1-mlogloss:1.02060
# [20]	validation_0-merror:0.20833	validation_0-mlogloss:0.98226	validation_1-merror:0.29895	validation_1-mlogloss:1.01721
# [21]	validation_0-merror:0.20675	validation_0-mlogloss:0.97766	validation_1-merror:0.30947	validation_1-mlogloss:1.01687
# [22]	validation_0-merror:0.20517	validation_0-mlogloss:0.97287	validation_1-merror:0.31158	validation_1-mlogloss:1.01409
# [23]	validation_0-merror:0.21414	validation_0-mlogloss:0.96854	validation_1-merror:0.29895	validation_1-mlogloss:1.01295
# [24]	validation_0-merror:0.21255	validation_0-mlogloss:0.96382	validation_1-merror:0.30316	validation_1-mlogloss:1.01028
# [25]	validation_0-merror:0.21255	validation_0-mlogloss:0.95897	validation_1-merror:0.29895	validation_1-mlogloss:1.00830
# [26]	validation_0-merror:0.21308	validation_0-mlogloss:0.95460	validation_1-merror:0.29895	validation_1-mlogloss:1.00629
# [27]	validation_0-merror:0.20992	validation_0-mlogloss:0.94981	validation_1-merror:0.30316	validation_1-mlogloss:1.00265
# [28]	validation_0-merror:0.20886	validation_0-mlogloss:0.94564	validation_1-merror:0.29474	validation_1-mlogloss:0.99929
# [29]	validation_0-merror:0.20939	validation_0-mlogloss:0.94115	validation_1-merror:0.30105	validation_1-mlogloss:0.99733
# [30]	validation_0-merror:0.20992	validation_0-mlogloss:0.93674	validation_1-merror:0.30105	validation_1-mlogloss:0.99541
# [31]	validation_0-merror:0.21255	validation_0-mlogloss:0.93255	validation_1-merror:0.30105	validation_1-mlogloss:0.99257
# [32]	validation_0-merror:0.21097	validation_0-mlogloss:0.92825	validation_1-merror:0.30105	validation_1-mlogloss:0.99160
# [33]	validation_0-merror:0.20833	validation_0-mlogloss:0.92376	validation_1-merror:0.30105	validation_1-mlogloss:0.98818
# [34]	validation_0-merror:0.20833	validation_0-mlogloss:0.91963	validation_1-merror:0.29684	validation_1-mlogloss:0.98421
# [35]	validation_0-merror:0.21097	validation_0-mlogloss:0.91552	validation_1-merror:0.29684	validation_1-mlogloss:0.98250
# [36]	validation_0-merror:0.20675	validation_0-mlogloss:0.91156	validation_1-merror:0.29474	validation_1-mlogloss:0.97887
# [37]	validation_0-merror:0.20728	validation_0-mlogloss:0.90769	validation_1-merror:0.28842	validation_1-mlogloss:0.97564
# [38]	validation_0-merror:0.20833	validation_0-mlogloss:0.90331	validation_1-merror:0.28632	validation_1-mlogloss:0.97387
# [39]	validation_0-merror:0.20622	validation_0-mlogloss:0.89951	validation_1-merror:0.28632	validation_1-mlogloss:0.97125
# [40]	validation_0-merror:0.20781	validation_0-mlogloss:0.89586	validation_1-merror:0.28632	validation_1-mlogloss:0.96979
# [41]	validation_0-merror:0.20728	validation_0-mlogloss:0.89164	validation_1-merror:0.29474	validation_1-mlogloss:0.96784
# [42]	validation_0-merror:0.20728	validation_0-mlogloss:0.88791	validation_1-merror:0.29684	validation_1-mlogloss:0.96555
# [43]	validation_0-merror:0.20517	validation_0-mlogloss:0.88398	validation_1-merror:0.29263	validation_1-mlogloss:0.96322
# [44]	validation_0-merror:0.20781	validation_0-mlogloss:0.88042	validation_1-merror:0.29684	validation_1-mlogloss:0.96163
# [45]	validation_0-merror:0.20833	validation_0-mlogloss:0.87662	validation_1-merror:0.29895	validation_1-mlogloss:0.96012
# [46]	validation_0-merror:0.20886	validation_0-mlogloss:0.87281	validation_1-merror:0.29263	validation_1-mlogloss:0.95851
# [47]	validation_0-merror:0.20570	validation_0-mlogloss:0.86936	validation_1-merror:0.29263	validation_1-mlogloss:0.95721
# [48]	validation_0-merror:0.20781	validation_0-mlogloss:0.86558	validation_1-merror:0.29895	validation_1-mlogloss:0.95598
# [49]	validation_0-merror:0.20886	validation_0-mlogloss:0.86164	validation_1-merror:0.29053	validation_1-mlogloss:0.95228
# [50]	validation_0-merror:0.20781	validation_0-mlogloss:0.85806	validation_1-merror:0.29474	validation_1-mlogloss:0.95003
# [51]	validation_0-merror:0.20833	validation_0-mlogloss:0.85424	validation_1-merror:0.29684	validation_1-mlogloss:0.94703
# [52]	validation_0-merror:0.20675	validation_0-mlogloss:0.85092	validation_1-merror:0.29053	validation_1-mlogloss:0.94564
# [53]	validation_0-merror:0.20781	validation_0-mlogloss:0.84743	validation_1-merror:0.29474	validation_1-mlogloss:0.94322
# [54]	validation_0-merror:0.20411	validation_0-mlogloss:0.84393	validation_1-merror:0.29474	validation_1-mlogloss:0.94086
# [55]	validation_0-merror:0.20570	validation_0-mlogloss:0.84064	validation_1-merror:0.29474	validation_1-mlogloss:0.93937
# [56]	validation_0-merror:0.20411	validation_0-mlogloss:0.83739	validation_1-merror:0.29684	validation_1-mlogloss:0.93787
# [57]	validation_0-merror:0.20517	validation_0-mlogloss:0.83389	validation_1-merror:0.29684	validation_1-mlogloss:0.93751
# [58]	validation_0-merror:0.20359	validation_0-mlogloss:0.83048	validation_1-merror:0.29684	validation_1-mlogloss:0.93684
# [59]	validation_0-merror:0.20306	validation_0-mlogloss:0.82742	validation_1-merror:0.29263	validation_1-mlogloss:0.93392
# [60]	validation_0-merror:0.20359	validation_0-mlogloss:0.82414	validation_1-merror:0.29053	validation_1-mlogloss:0.93248
# [61]	validation_0-merror:0.20306	validation_0-mlogloss:0.82133	validation_1-merror:0.29263	validation_1-mlogloss:0.93118
# [62]	validation_0-merror:0.20359	validation_0-mlogloss:0.81816	validation_1-merror:0.28842	validation_1-mlogloss:0.92892
# [63]	validation_0-merror:0.20306	validation_0-mlogloss:0.81518	validation_1-merror:0.29263	validation_1-mlogloss:0.92865
# [64]	validation_0-merror:0.20464	validation_0-mlogloss:0.81207	validation_1-merror:0.28632	validation_1-mlogloss:0.92603
# [65]	validation_0-merror:0.20570	validation_0-mlogloss:0.80894	validation_1-merror:0.28842	validation_1-mlogloss:0.92349
# [66]	validation_0-merror:0.20517	validation_0-mlogloss:0.80568	validation_1-merror:0.29053	validation_1-mlogloss:0.92210
# [67]	validation_0-merror:0.20464	validation_0-mlogloss:0.80252	validation_1-merror:0.29053	validation_1-mlogloss:0.91961
# [68]	validation_0-merror:0.20517	validation_0-mlogloss:0.79933	validation_1-merror:0.28842	validation_1-mlogloss:0.91803
# [69]	validation_0-merror:0.20517	validation_0-mlogloss:0.79655	validation_1-merror:0.29053	validation_1-mlogloss:0.91608
# [70]	validation_0-merror:0.20359	validation_0-mlogloss:0.79344	validation_1-merror:0.28632	validation_1-mlogloss:0.91369
# [71]	validation_0-merror:0.20306	validation_0-mlogloss:0.79031	validation_1-merror:0.28421	validation_1-mlogloss:0.91253
# [72]	validation_0-merror:0.20253	validation_0-mlogloss:0.78754	validation_1-merror:0.28421	validation_1-mlogloss:0.91094
# [73]	validation_0-merror:0.20148	validation_0-mlogloss:0.78470	validation_1-merror:0.28211	validation_1-mlogloss:0.90965
# [74]	validation_0-merror:0.20464	validation_0-mlogloss:0.78192	validation_1-merror:0.28421	validation_1-mlogloss:0.90839
# [75]	validation_0-merror:0.20411	validation_0-mlogloss:0.77888	validation_1-merror:0.28632	validation_1-mlogloss:0.90672
# [76]	validation_0-merror:0.20306	validation_0-mlogloss:0.77584	validation_1-merror:0.28842	validation_1-mlogloss:0.90503
# [77]	validation_0-merror:0.20253	validation_0-mlogloss:0.77303	validation_1-merror:0.28632	validation_1-mlogloss:0.90314
# [78]	validation_0-merror:0.20200	validation_0-mlogloss:0.77036	validation_1-merror:0.28632	validation_1-mlogloss:0.90155
# [79]	validation_0-merror:0.20253	validation_0-mlogloss:0.76764	validation_1-merror:0.29263	validation_1-mlogloss:0.89907
# [80]	validation_0-merror:0.20306	validation_0-mlogloss:0.76473	validation_1-merror:0.29474	validation_1-mlogloss:0.89839
# [81]	validation_0-merror:0.20200	validation_0-mlogloss:0.76224	validation_1-merror:0.29684	validation_1-mlogloss:0.89855
# [82]	validation_0-merror:0.20095	validation_0-mlogloss:0.75974	validation_1-merror:0.29474	validation_1-mlogloss:0.89734
# [83]	validation_0-merror:0.20306	validation_0-mlogloss:0.75730	validation_1-merror:0.29263	validation_1-mlogloss:0.89438
# [84]	validation_0-merror:0.20200	validation_0-mlogloss:0.75464	validation_1-merror:0.29053	validation_1-mlogloss:0.89267
# [85]	validation_0-merror:0.19989	validation_0-mlogloss:0.75207	validation_1-merror:0.28632	validation_1-mlogloss:0.89146
# [86]	validation_0-merror:0.19778	validation_0-mlogloss:0.74948	validation_1-merror:0.28842	validation_1-mlogloss:0.88994
# [87]	validation_0-merror:0.19726	validation_0-mlogloss:0.74694	validation_1-merror:0.28842	validation_1-mlogloss:0.88897
# [36]	validation_0-merror:0.20200	validation_0-mlogloss:0.91559	validation_1-merror:0.28421	validation_1-mlogloss:0.97450
# [37]	validation_0-merror:0.20148	validation_0-mlogloss:0.91173	validation_1-merror:0.27789	validation_1-mlogloss:0.97147
# [38]	validation_0-merror:0.20200	validation_0-mlogloss:0.90772	validation_1-merror:0.27789	validation_1-mlogloss:0.96802
# [39]	validation_0-merror:0.19937	validation_0-mlogloss:0.90372	validation_1-merror:0.27579	validation_1-mlogloss:0.96414
# [40]	validation_0-merror:0.20200	validation_0-mlogloss:0.89967	validation_1-merror:0.27789	validation_1-mlogloss:0.96253
# [41]	validation_0-merror:0.20148	validation_0-mlogloss:0.89590	validation_1-merror:0.27789	validation_1-mlogloss:0.96014
# [42]	validation_0-merror:0.20411	validation_0-mlogloss:0.89207	validation_1-merror:0.28211	validation_1-mlogloss:0.95889
# [43]	validation_0-merror:0.20464	validation_0-mlogloss:0.88872	validation_1-merror:0.28211	validation_1-mlogloss:0.95562
# [44]	validation_0-merror:0.20253	validation_0-mlogloss:0.88495	validation_1-merror:0.27789	validation_1-mlogloss:0.95361
# [45]	validation_0-merror:0.20148	validation_0-mlogloss:0.88138	validation_1-merror:0.28421	validation_1-mlogloss:0.95189
# [46]	validation_0-merror:0.20042	validation_0-mlogloss:0.87750	validation_1-merror:0.28842	validation_1-mlogloss:0.94934
# [47]	validation_0-merror:0.20200	validation_0-mlogloss:0.87399	validation_1-merror:0.27579	validation_1-mlogloss:0.94716
# [48]	validation_0-merror:0.20253	validation_0-mlogloss:0.86989	validation_1-merror:0.28211	validation_1-mlogloss:0.94593
# [49]	validation_0-merror:0.20253	validation_0-mlogloss:0.86612	validation_1-merror:0.28000	validation_1-mlogloss:0.94355
# [50]	validation_0-merror:0.20359	validation_0-mlogloss:0.86283	validation_1-merror:0.28421	validation_1-mlogloss:0.94101
# [51]	validation_0-merror:0.20359	validation_0-mlogloss:0.85948	validation_1-merror:0.28000	validation_1-mlogloss:0.93782
# [52]	validation_0-merror:0.20253	validation_0-mlogloss:0.85627	validation_1-merror:0.28211	validation_1-mlogloss:0.93653
# [53]	validation_0-merror:0.20464	validation_0-mlogloss:0.85290	validation_1-merror:0.28632	validation_1-mlogloss:0.93519
# [54]	validation_0-merror:0.20306	validation_0-mlogloss:0.84947	validation_1-merror:0.28211	validation_1-mlogloss:0.93174
# [55]	validation_0-merror:0.20095	validation_0-mlogloss:0.84613	validation_1-merror:0.28421	validation_1-mlogloss:0.93044
# [56]	validation_0-merror:0.20095	validation_0-mlogloss:0.84286	validation_1-merror:0.28211	validation_1-mlogloss:0.92816
# [57]	validation_0-merror:0.20253	validation_0-mlogloss:0.83943	validation_1-merror:0.27789	validation_1-mlogloss:0.92583
# [58]	validation_0-merror:0.20200	validation_0-mlogloss:0.83597	validation_1-merror:0.28211	validation_1-mlogloss:0.92436
# [59]	validation_0-merror:0.20042	validation_0-mlogloss:0.83314	validation_1-merror:0.28000	validation_1-mlogloss:0.92191
# [60]	validation_0-merror:0.19937	validation_0-mlogloss:0.82983	validation_1-merror:0.27368	validation_1-mlogloss:0.92070
# [61]	validation_0-merror:0.19937	validation_0-mlogloss:0.82665	validation_1-merror:0.28211	validation_1-mlogloss:0.92171
# [62]	validation_0-merror:0.19989	validation_0-mlogloss:0.82329	validation_1-merror:0.28632	validation_1-mlogloss:0.91859
# [63]	validation_0-merror:0.19831	validation_0-mlogloss:0.82027	validation_1-merror:0.28421	validation_1-mlogloss:0.91803
# [64]	validation_0-merror:0.19778	validation_0-mlogloss:0.81723	validation_1-merror:0.28632	validation_1-mlogloss:0.91447
# [65]	validation_0-merror:0.19831	validation_0-mlogloss:0.81418	validation_1-merror:0.28211	validation_1-mlogloss:0.91193
# [66]	validation_0-merror:0.19884	validation_0-mlogloss:0.81100	validation_1-merror:0.27789	validation_1-mlogloss:0.90963
# [67]	validation_0-merror:0.19778	validation_0-mlogloss:0.80845	validation_1-merror:0.27579	validation_1-mlogloss:0.90725
# [68]	validation_0-merror:0.19778	validation_0-mlogloss:0.80534	validation_1-merror:0.27789	validation_1-mlogloss:0.90447
# [69]	validation_0-merror:0.19937	validation_0-mlogloss:0.80255	validation_1-merror:0.28000	validation_1-mlogloss:0.90313
# [70]	validation_0-merror:0.19778	validation_0-mlogloss:0.79950	validation_1-merror:0.27579	validation_1-mlogloss:0.90110
# [71]	validation_0-merror:0.19831	validation_0-mlogloss:0.79631	validation_1-merror:0.28211	validation_1-mlogloss:0.89982
# [72]	validation_0-merror:0.19726	validation_0-mlogloss:0.79354	validation_1-merror:0.27789	validation_1-mlogloss:0.89739
# [73]	validation_0-merror:0.19673	validation_0-mlogloss:0.79039	validation_1-merror:0.28211	validation_1-mlogloss:0.89553
# [74]	validation_0-merror:0.19515	validation_0-mlogloss:0.78759	validation_1-merror:0.28211	validation_1-mlogloss:0.89323
# [75]	validation_0-merror:0.19620	validation_0-mlogloss:0.78462	validation_1-merror:0.28632	validation_1-mlogloss:0.89124
# [76]	validation_0-merror:0.19620	validation_0-mlogloss:0.78155	validation_1-merror:0.28632	validation_1-mlogloss:0.88960
# [77]	validation_0-merror:0.19462	validation_0-mlogloss:0.77875	validation_1-merror:0.28421	validation_1-mlogloss:0.88733
# [78]	validation_0-merror:0.19620	validation_0-mlogloss:0.77639	validation_1-merror:0.28632	validation_1-mlogloss:0.88647
# [79]	validation_0-merror:0.19568	validation_0-mlogloss:0.77355	validation_1-merror:0.28632	validation_1-mlogloss:0.88515
# [80]	validation_0-merror:0.19462	validation_0-mlogloss:0.77038	validation_1-merror:0.28421	validation_1-mlogloss:0.88486
# [81]	validation_0-merror:0.19462	validation_0-mlogloss:0.76791	validation_1-merror:0.28842	validation_1-mlogloss:0.88349
# [82]	validation_0-merror:0.19409	validation_0-mlogloss:0.76543	validation_1-merror:0.28842	validation_1-mlogloss:0.88133
# [83]	validation_0-merror:0.19462	validation_0-mlogloss:0.76278	validation_1-merror:0.28632	validation_1-mlogloss:0.87934
# [84]	validation_0-merror:0.19462	validation_0-mlogloss:0.76037	validation_1-merror:0.28842	validation_1-mlogloss:0.87770
# [85]	validation_0-merror:0.19304	validation_0-mlogloss:0.75794	validation_1-merror:0.28842	validation_1-mlogloss:0.87653
# wandb: Network error (TransientError), entering retry loop.
# [86]	validation_0-merror:0.19198	validation_0-mlogloss:0.75507	validation_1-merror:0.28632	validation_1-mlogloss:0.87436
# [87]	validation_0-merror:0.19040	validation_0-mlogloss:0.75277	validation_1-merror:0.28421	validation_1-mlogloss:0.87292
# [88]	validation_0-merror:0.18882	validation_0-mlogloss:0.74976	validation_1-merror:0.28421	validation_1-mlogloss:0.87065
# [89]	validation_0-merror:0.19146	validation_0-mlogloss:0.74731	validation_1-merror:0.28421	validation_1-mlogloss:0.86952
# [90]	validation_0-merror:0.19251	validation_0-mlogloss:0.74487	validation_1-merror:0.28632	validation_1-mlogloss:0.86901
# [91]	validation_0-merror:0.19251	validation_0-mlogloss:0.74266	validation_1-merror:0.28421	validation_1-mlogloss:0.86682
# [92]	validation_0-merror:0.19198	validation_0-mlogloss:0.74005	validation_1-merror:0.28632	validation_1-mlogloss:0.86590
# [93]	validation_0-merror:0.19251	validation_0-mlogloss:0.73768	validation_1-merror:0.28632	validation_1-mlogloss:0.86481
# [94]	validation_0-merror:0.19146	validation_0-mlogloss:0.73525	validation_1-merror:0.28421	validation_1-mlogloss:0.86249
# [95]	validation_0-merror:0.19251	validation_0-mlogloss:0.73262	validation_1-merror:0.28421	validation_1-mlogloss:0.86116
# [96]	validation_0-merror:0.19146	validation_0-mlogloss:0.73022	validation_1-merror:0.28421	validation_1-mlogloss:0.85970
# [97]	validation_0-merror:0.19146	validation_0-mlogloss:0.72778	validation_1-merror:0.28211	validation_1-mlogloss:0.85726
# [98]	validation_0-merror:0.19251	validation_0-mlogloss:0.72525	validation_1-merror:0.28000	validation_1-mlogloss:0.85624
# [99]	validation_0-merror:0.18935	validation_0-mlogloss:0.72293	validation_1-merror:0.28000	validation_1-mlogloss:0.85589
# [0]	validation_0-merror:0.30116	validation_0-mlogloss:1.09249	validation_1-merror:0.41263	validation_1-mlogloss:1.09427
# [1]	validation_0-merror:0.27321	validation_0-mlogloss:1.08631	validation_1-merror:0.40211	validation_1-mlogloss:1.09019
# [2]	validation_0-merror:0.24842	validation_0-mlogloss:1.08051	validation_1-merror:0.39789	validation_1-mlogloss:1.08588
# [3]	validation_0-merror:0.23576	validation_0-mlogloss:1.07429	validation_1-merror:0.35789	validation_1-mlogloss:1.08081
# [4]	validation_0-merror:0.23154	validation_0-mlogloss:1.06835	validation_1-merror:0.37895	validation_1-mlogloss:1.08031
# [5]	validation_0-merror:0.22785	validation_0-mlogloss:1.06225	validation_1-merror:0.38737	validation_1-mlogloss:1.07869
# [6]	validation_0-merror:0.22574	validation_0-mlogloss:1.05613	validation_1-merror:0.37895	validation_1-mlogloss:1.07478
# [7]	validation_0-merror:0.22521	validation_0-mlogloss:1.05068	validation_1-merror:0.33474	validation_1-mlogloss:1.07019
# [8]	validation_0-merror:0.22574	validation_0-mlogloss:1.04548	validation_1-merror:0.32000	validation_1-mlogloss:1.06534
# [33]	validation_0-merror:0.21150	validation_0-mlogloss:0.92491	validation_1-merror:0.30105	validation_1-mlogloss:0.98354
# [34]	validation_0-merror:0.21361	validation_0-mlogloss:0.92105	validation_1-merror:0.30105	validation_1-mlogloss:0.98103
# [35]	validation_0-merror:0.21308	validation_0-mlogloss:0.91692	validation_1-merror:0.30526	validation_1-mlogloss:0.97939
# [36]	validation_0-merror:0.20728	validation_0-mlogloss:0.91263	validation_1-merror:0.29684	validation_1-mlogloss:0.97476
# [37]	validation_0-merror:0.21624	validation_0-mlogloss:0.90869	validation_1-merror:0.28842	validation_1-mlogloss:0.97166
# [38]	validation_0-merror:0.21414	validation_0-mlogloss:0.90482	validation_1-merror:0.29053	validation_1-mlogloss:0.96823
# [39]	validation_0-merror:0.21203	validation_0-mlogloss:0.90064	validation_1-merror:0.29474	validation_1-mlogloss:0.96578
# [40]	validation_0-merror:0.20939	validation_0-mlogloss:0.89694	validation_1-merror:0.28632	validation_1-mlogloss:0.96373
# [41]	validation_0-merror:0.20886	validation_0-mlogloss:0.89299	validation_1-merror:0.29263	validation_1-mlogloss:0.96143
# [42]	validation_0-merror:0.21255	validation_0-mlogloss:0.88908	validation_1-merror:0.29263	validation_1-mlogloss:0.95852
# [43]	validation_0-merror:0.21044	validation_0-mlogloss:0.88521	validation_1-merror:0.29263	validation_1-mlogloss:0.95583
# [44]	validation_0-merror:0.20781	validation_0-mlogloss:0.88164	validation_1-merror:0.29474	validation_1-mlogloss:0.95412
# [45]	validation_0-merror:0.20781	validation_0-mlogloss:0.87804	validation_1-merror:0.29684	validation_1-mlogloss:0.95224
# [46]	validation_0-merror:0.20675	validation_0-mlogloss:0.87415	validation_1-merror:0.29053	validation_1-mlogloss:0.95089
# [47]	validation_0-merror:0.20675	validation_0-mlogloss:0.87063	validation_1-merror:0.29474	validation_1-mlogloss:0.94927
# [48]	validation_0-merror:0.20570	validation_0-mlogloss:0.86690	validation_1-merror:0.29263	validation_1-mlogloss:0.94693
# [49]	validation_0-merror:0.20675	validation_0-mlogloss:0.86331	validation_1-merror:0.28842	validation_1-mlogloss:0.94438
# [50]	validation_0-merror:0.20622	validation_0-mlogloss:0.85977	validation_1-merror:0.29263	validation_1-mlogloss:0.94155
# [51]	validation_0-merror:0.20622	validation_0-mlogloss:0.85599	validation_1-merror:0.28842	validation_1-mlogloss:0.93809
# [52]	validation_0-merror:0.20517	validation_0-mlogloss:0.85245	validation_1-merror:0.29474	validation_1-mlogloss:0.93784
# [53]	validation_0-merror:0.20464	validation_0-mlogloss:0.84917	validation_1-merror:0.29053	validation_1-mlogloss:0.93723
# [54]	validation_0-merror:0.20622	validation_0-mlogloss:0.84560	validation_1-merror:0.29263	validation_1-mlogloss:0.93533
# [55]	validation_0-merror:0.20675	validation_0-mlogloss:0.84222	validation_1-merror:0.29474	validation_1-mlogloss:0.93463
# [56]	validation_0-merror:0.20622	validation_0-mlogloss:0.83859	validation_1-merror:0.29474	validation_1-mlogloss:0.93239
# [57]	validation_0-merror:0.20517	validation_0-mlogloss:0.83535	validation_1-merror:0.29474	validation_1-mlogloss:0.93154
# [58]	validation_0-merror:0.20253	validation_0-mlogloss:0.83190	validation_1-merror:0.29895	validation_1-mlogloss:0.93068
# [59]	validation_0-merror:0.20200	validation_0-mlogloss:0.82913	validation_1-merror:0.29474	validation_1-mlogloss:0.92955
# [60]	validation_0-merror:0.20095	validation_0-mlogloss:0.82562	validation_1-merror:0.29053	validation_1-mlogloss:0.92711
# [61]	validation_0-merror:0.19937	validation_0-mlogloss:0.82245	validation_1-merror:0.29263	validation_1-mlogloss:0.92621
# [62]	validation_0-merror:0.19937	validation_0-mlogloss:0.81940	validation_1-merror:0.29474	validation_1-mlogloss:0.92410
# [63]	validation_0-merror:0.19989	validation_0-mlogloss:0.81649	validation_1-merror:0.29684	validation_1-mlogloss:0.92201
# [64]	validation_0-merror:0.19937	validation_0-mlogloss:0.81395	validation_1-merror:0.29474	validation_1-mlogloss:0.91996
# [65]	validation_0-merror:0.20095	validation_0-mlogloss:0.81083	validation_1-merror:0.29895	validation_1-mlogloss:0.91745
# [66]	validation_0-merror:0.19989	validation_0-mlogloss:0.80767	validation_1-merror:0.30316	validation_1-mlogloss:0.91563
# [67]	validation_0-merror:0.19831	validation_0-mlogloss:0.80467	validation_1-merror:0.29895	validation_1-mlogloss:0.91347
# [68]	validation_0-merror:0.19726	validation_0-mlogloss:0.80177	validation_1-merror:0.29263	validation_1-mlogloss:0.91167
# [69]	validation_0-merror:0.19726	validation_0-mlogloss:0.79868	validation_1-merror:0.29053	validation_1-mlogloss:0.90954
# [70]	validation_0-merror:0.19515	validation_0-mlogloss:0.79555	validation_1-merror:0.28842	validation_1-mlogloss:0.90716
# [71]	validation_0-merror:0.19778	validation_0-mlogloss:0.79284	validation_1-merror:0.28842	validation_1-mlogloss:0.90414
# [72]	validation_0-merror:0.19726	validation_0-mlogloss:0.79022	validation_1-merror:0.28632	validation_1-mlogloss:0.90287
# [73]	validation_0-merror:0.19884	validation_0-mlogloss:0.78729	validation_1-merror:0.28421	validation_1-mlogloss:0.90063
# [74]	validation_0-merror:0.19989	validation_0-mlogloss:0.78478	validation_1-merror:0.28211	validation_1-mlogloss:0.89835
# [75]	validation_0-merror:0.19937	validation_0-mlogloss:0.78198	validation_1-merror:0.28421	validation_1-mlogloss:0.89655
# [76]	validation_0-merror:0.19673	validation_0-mlogloss:0.77947	validation_1-merror:0.28421	validation_1-mlogloss:0.89608
# [77]	validation_0-merror:0.19989	validation_0-mlogloss:0.77691	validation_1-merror:0.28211	validation_1-mlogloss:0.89497
# [78]	validation_0-merror:0.19778	validation_0-mlogloss:0.77419	validation_1-merror:0.28421	validation_1-mlogloss:0.89463
# [79]	validation_0-merror:0.19778	validation_0-mlogloss:0.77123	validation_1-merror:0.28632	validation_1-mlogloss:0.89402
# [80]	validation_0-merror:0.19726	validation_0-mlogloss:0.76877	validation_1-merror:0.28632	validation_1-mlogloss:0.89340
# [81]	validation_0-merror:0.19831	validation_0-mlogloss:0.76612	validation_1-merror:0.28632	validation_1-mlogloss:0.89264
# [82]	validation_0-merror:0.19937	validation_0-mlogloss:0.76376	validation_1-merror:0.28842	validation_1-mlogloss:0.89052
# [83]	validation_0-merror:0.19884	validation_0-mlogloss:0.76111	validation_1-merror:0.29263	validation_1-mlogloss:0.88885
# [84]	validation_0-merror:0.19831	validation_0-mlogloss:0.75870	validation_1-merror:0.29053	validation_1-mlogloss:0.88657
# [85]	validation_0-merror:0.19831	validation_0-mlogloss:0.75624	validation_1-merror:0.29474	validation_1-mlogloss:0.88562
# [86]	validation_0-merror:0.19831	validation_0-mlogloss:0.75379	validation_1-merror:0.29474	validation_1-mlogloss:0.88362
# [87]	validation_0-merror:0.19778	validation_0-mlogloss:0.75132	validation_1-merror:0.29053	validation_1-mlogloss:0.88170
# [88]	validation_0-merror:0.19673	validation_0-mlogloss:0.74894	validation_1-merror:0.29053	validation_1-mlogloss:0.87980
# [89]	validation_0-merror:0.19778	validation_0-mlogloss:0.74672	validation_1-merror:0.28842	validation_1-mlogloss:0.87843
# [90]	validation_0-merror:0.19778	validation_0-mlogloss:0.74446	validation_1-merror:0.29053	validation_1-mlogloss:0.87650
# [91]	validation_0-merror:0.19831	validation_0-mlogloss:0.74197	validation_1-merror:0.29263	validation_1-mlogloss:0.87572
# [92]	validation_0-merror:0.19620	validation_0-mlogloss:0.73949	validation_1-merror:0.28632	validation_1-mlogloss:0.87316
# [93]	validation_0-merror:0.19568	validation_0-mlogloss:0.73710	validation_1-merror:0.28842	validation_1-mlogloss:0.87242
# [94]	validation_0-merror:0.19673	validation_0-mlogloss:0.73484	validation_1-merror:0.28632	validation_1-mlogloss:0.86987
# [95]	validation_0-merror:0.19515	validation_0-mlogloss:0.73229	validation_1-merror:0.28842	validation_1-mlogloss:0.86942
# [96]	validation_0-merror:0.19568	validation_0-mlogloss:0.73000	validation_1-merror:0.28632	validation_1-mlogloss:0.86708
# [97]	validation_0-merror:0.19568	validation_0-mlogloss:0.72776	validation_1-merror:0.28421	validation_1-mlogloss:0.86512
# [98]	validation_0-merror:0.19515	validation_0-mlogloss:0.72571	validation_1-merror:0.28421	validation_1-mlogloss:0.86468
# [99]	validation_0-merror:0.19462	validation_0-mlogloss:0.72373	validation_1-merror:0.28000	validation_1-mlogloss:0.86308
# [0]	validation_0-merror:0.30380	validation_0-mlogloss:1.09221	validation_1-merror:0.27789	validation_1-mlogloss:1.09183
# [1]	validation_0-merror:0.25527	validation_0-mlogloss:1.08565	validation_1-merror:0.27789	validation_1-mlogloss:1.08596
# [2]	validation_0-merror:0.23629	validation_0-mlogloss:1.07937	validation_1-merror:0.27579	validation_1-mlogloss:1.08246
# [3]	validation_0-merror:0.22468	validation_0-mlogloss:1.07311	validation_1-merror:0.29053	validation_1-mlogloss:1.07745
# [4]	validation_0-merror:0.22574	validation_0-mlogloss:1.06716	validation_1-merror:0.30105	validation_1-mlogloss:1.07420
# [5]	validation_0-merror:0.22046	validation_0-mlogloss:1.06069	validation_1-merror:0.28842	validation_1-mlogloss:1.07130
# [26]	validation_0-merror:0.30169	validation_0-mlogloss:0.99451	validation_1-merror:0.26105	validation_1-mlogloss:0.99860
# [27]	validation_0-merror:0.30274	validation_0-mlogloss:0.99128	validation_1-merror:0.26105	validation_1-mlogloss:0.99599
# [28]	validation_0-merror:0.30327	validation_0-mlogloss:0.98787	validation_1-merror:0.26316	validation_1-mlogloss:0.99519
# [29]	validation_0-merror:0.30274	validation_0-mlogloss:0.98441	validation_1-merror:0.26526	validation_1-mlogloss:0.99217
# [30]	validation_0-merror:0.30169	validation_0-mlogloss:0.98160	validation_1-merror:0.26737	validation_1-mlogloss:0.98971
# [31]	validation_0-merror:0.30011	validation_0-mlogloss:0.97848	validation_1-merror:0.26316	validation_1-mlogloss:0.98682
# [32]	validation_0-merror:0.30063	validation_0-mlogloss:0.97553	validation_1-merror:0.25684	validation_1-mlogloss:0.98296
# [33]	validation_0-merror:0.29905	validation_0-mlogloss:0.97231	validation_1-merror:0.25684	validation_1-mlogloss:0.97941
# [34]	validation_0-merror:0.30116	validation_0-mlogloss:0.96966	validation_1-merror:0.25684	validation_1-mlogloss:0.97706
# [35]	validation_0-merror:0.30169	validation_0-mlogloss:0.96636	validation_1-merror:0.26105	validation_1-mlogloss:0.97399
# [36]	validation_0-merror:0.30327	validation_0-mlogloss:0.96342	validation_1-merror:0.26105	validation_1-mlogloss:0.97147
# [37]	validation_0-merror:0.30169	validation_0-mlogloss:0.96083	validation_1-merror:0.26105	validation_1-mlogloss:0.96893
# [38]	validation_0-merror:0.29958	validation_0-mlogloss:0.95799	validation_1-merror:0.26316	validation_1-mlogloss:0.96650
# [39]	validation_0-merror:0.29905	validation_0-mlogloss:0.95502	validation_1-merror:0.26737	validation_1-mlogloss:0.96413
# [40]	validation_0-merror:0.29958	validation_0-mlogloss:0.95226	validation_1-merror:0.26947	validation_1-mlogloss:0.96107
# [41]	validation_0-merror:0.29852	validation_0-mlogloss:0.94977	validation_1-merror:0.26526	validation_1-mlogloss:0.95859
# [42]	validation_0-merror:0.29800	validation_0-mlogloss:0.94705	validation_1-merror:0.26526	validation_1-mlogloss:0.95644
# [43]	validation_0-merror:0.29958	validation_0-mlogloss:0.94464	validation_1-merror:0.26737	validation_1-mlogloss:0.95386
# [44]	validation_0-merror:0.29747	validation_0-mlogloss:0.94226	validation_1-merror:0.26526	validation_1-mlogloss:0.95314
# [45]	validation_0-merror:0.29747	validation_0-mlogloss:0.93987	validation_1-merror:0.26737	validation_1-mlogloss:0.94942
# [46]	validation_0-merror:0.29800	validation_0-mlogloss:0.93719	validation_1-merror:0.26737	validation_1-mlogloss:0.94689
# [47]	validation_0-merror:0.29958	validation_0-mlogloss:0.93446	validation_1-merror:0.26526	validation_1-mlogloss:0.94467
# [48]	validation_0-merror:0.29852	validation_0-mlogloss:0.93191	validation_1-merror:0.26526	validation_1-mlogloss:0.94320
# [49]	validation_0-merror:0.29800	validation_0-mlogloss:0.92945	validation_1-merror:0.26316	validation_1-mlogloss:0.94130
# Buying 6 shares for 151.60. Remaining Balance: 90.40000000000009
# Selling all shares for
MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_iteration</td><td>▁████▄▄▃▃███▅▅▂▄████▄▄▄▄▄▄▄▃▄▄▄▄▂▂▄▂███▄</td></tr><tr><td>best_score</td><td>▅▄▅▄▄▂▂▁▂███▁▁▃▁████▆▆▆▆▂▂▂▂▆▆▆▆▂▂▁▂███▆</td></tr><tr><td>epoch</td><td>▃▅▅▄▄▃▂▂▁█▇▇▆▆▂▃▅▅▅▄▃▃▂▂▁▃▃▄▄▃▂▅▅▃▃▂▂▁█▇</td></tr><tr><td>validation_0-merror</td><td>▃▂▁▃▂▂▄▅▃▃▂▃▂▂█▆▅▅▆▅▆▆▇▇█▂▁▁▁▄▅▅▄▆▇▇▇█▇▇</td></tr><tr><td>validation_0-mlogloss</td><td>▆▅▅▆▆▆▃▄█▇▇▇██▄▃▃█████▇▇█▂▂▁▁▇▇▃▃▃██████</td></tr><tr><td>validation_1-merror</td><td>▅▄▅▆▃▃▄▃█▃▄▇▃▁▃▅▂▃▄▅▃▃▃▄▃▄▄▃▃▄▃▃▅▃▄▃▃▃▃▂</td></tr><tr><td>validation_1-mlogloss</td><td>▆▅▆▆▆▇▂▃█▇▇█▇█▂▂▁█████▇▇█▂▂▂▃▇▇▁▂▂████▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Buy And Hold (Base ROI)</td><td>62.64</td></tr><tr><td>Max ROI</td><td>2121.475</td></tr><tr><td>ROI</td><td>324.96</td></tr><tr><td>accuracy</td><td>0.73684</td></tr><tr><td>best_iteration</td><td>49</td></tr><tr><td>best_score</td><td>0.9413</td></tr><tr><td>epoch</td><td>49</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">XGBoostClassifier_shuffled_1721697390</strong> at: <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/vy1gawj8' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/vy1gawj8</a><br/> View project at: <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a><br/>Synced 5 W&B file(s), 103 media file(s), 93 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240722_191630-vy1gawj8/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
results = xgb_gs.best_estimator_.evals_result()

# %%
epochs = len(results['validation_0']['mlogloss'])
x_axis = range(0, epochs)

# xgboost 'mlogloss' plot
fig, ax = plt.subplots(figsize=(9,5))
ax.plot(x_axis, results['validation_0']['mlogloss'], label='Train')
ax.plot(x_axis, results['validation_1']['mlogloss'], label='Test')
ax.legend()
plt.ylabel('mlogloss')
plt.title('GridSearchCV XGBoost mlogloss')
plt.show()

# xgboost 'merror' plot
fig, ax = plt.subplots(figsize=(9,5))
ax.plot(x_axis, results['validation_0']['merror'], label='Train')
ax.plot(x_axis, results['validation_1']['merror'], label='Test')
ax.legend()
plt.ylabel('merror')
plt.title('GridSearchCV XGBoost merror')
plt.show()

# %%
run.finish()

# %% [markdown]
# # XGBoost #2 using native API ( DMatrix, etc)

# %%
# we will change our main dataset slightly
#stockdf, targetdf, otherdf
from sklearn.preprocessing import OrdinalEncoder

# %%
y_train_xgb = pd.Categorical(y_train).codes
y_test_xgb = pd.Categorical(y_test).codes

y_encoded = OrdinalEncoder().fit_transform(targetdf)


#X_train, X_test, y_train, y_test = train_test_split(stockdf,y_encoded, train_size=0.8,shuffle=False)


train_xgb = xgb.DMatrix(X_train, y_train_xgb, enable_categorical=True)

test_xgb = xgb.DMatrix(X_test, y_test_xgb, enable_categorical=True)

# %%
import xgboost as xgb
from wandb.integration.xgboost import WandbCallback

run_name = f"XGBoostClassNative_shuffled_{int(time.time())}"
run = wandb.init(entity="christopherandrews", 
                project="StockPredictor", 
                name=run_name, save_code=False, 
                settings=wandb.Settings(start_method="fork"), 
                reinit=True, 
                sync_tensorboard=True,)

params = {"objective": "multi:softmax"
        , "device":"cuda"
        ,"num_class":3
        , 'max_depth': 2
        , 'learning_rate': 0.001
        , 'random_state': 42
        , 'eval_metric': ['auc']}

# alpha is L1 regularization - zeros some weights
#lambda is L2 regularization - smoother penalty
# params = {
#         "objective": "multi:softprob"
#         , "num_class":3
#         , 'gamma': 1               ## def: 0
#         , 'learning_rate': 0.1     ## def: 0.1
#         , 'max_depth': 3
#         , 'min_child_weight': 100  ## def: 1
#         , 'nthread': 24
#         , 'random_state': 42
#         , 'reg_alpha': 0
#         , 'reg_lambda': 0          ## def: 1
#         , 'eval_metric': ['auc', 'logloss']
#         , "device":"cuda" # use to train on GPU
#     }

evals = [(train_xgb, "train"), (test_xgb, "test")]
num_rounds = 100000

cls2 = xgb.train(params=params, 
                dtrain=train_xgb, 
                num_boost_round=num_rounds, 
                evals=evals, 
                verbose_eval=10, 
                early_stopping_rounds=200, 
                callbacks=[WandbCallback(log_feature_importance=True, importance_type="gain")])

y_pred_test_xgb = cls2.predict(test_xgb, iteration_range=(0, cls2.best_iteration + 1))

run.summary['accuracy'] = accuracy_score(y_test_xgb, y_pred_test_xgb)
print("Test Accuracy: ", accuracy_score(y_test_xgb, y_pred_test_xgb))
xgb_preds = pd.DataFrame(data=y_pred_test_xgb, columns=["Target"], index=y_test.index.copy())
xgb_preds['close'] = other_test['close']
run.summary["ROI"] = stockutils.calculate_total_gains_bhs(xgb_preds, init_value=1000, init_price=xgb_preds['close'][0])
run.summary["Buy And Hold (Base ROI)"] = bah_ROI
run.summary["Max ROI"] = max_ROI

wandb.sklearn.plot_confusion_matrix(y_test_xgb, y_pred_test_xgb)

run.finish()
# Out:
# wandb version 0.17.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/home/candrews/Projects/MyProjects/StockPredictor/notebooks/wandb/run-20240722_192024-dxo9gfxd</code>
# Syncing run <strong><a href='https://wandb.ai/christopherandrews/StockPredictor/runs/dxo9gfxd' target="_blank">XGBoostClassNative_shuffled_1721697624</a></strong> to <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a>
#  View run at <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/dxo9gfxd' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/dxo9gfxd</a>
# [0]	train-auc:0.82990	test-auc:0.84715
# [10]	train-auc:0.82990	test-auc:0.84715
# [20]	train-auc:0.82990	test-auc:0.84715
# [30]	train-auc:0.82990	test-auc:0.84715
# [40]	train-auc:0.83284	test-auc:0.84842
# [50]	train-auc:0.83286	test-auc:0.84839
# [60]	train-auc:0.83277	test-auc:0.84999
# [70]	train-auc:0.83807	test-auc:0.85416
# [80]	train-auc:0.83970	test-auc:0.85525
# [90]	train-auc:0.84168	test-auc:0.85606
# [100]	train-auc:0.84336	test-auc:0.85630
# [110]	train-auc:0.84451	test-auc:0.85671
# [120]	train-auc:0.84535	test-auc:0.85679
# [130]	train-auc:0.84625	test-auc:0.85652
# [140]	train-auc:0.84694	test-auc:0.85659
# [150]	train-auc:0.84776	test-auc:0.85724
# [160]	train-auc:0.84840	test-auc:0.85652
# [170]	train-auc:0.84864	test-auc:0.85688
# [180]	train-auc:0.84973	test-auc:0.85722
# [190]	train-auc:0.84999	test-auc:0.85655
# [200]	train-auc:0.85028	test-auc:0.85663
# [210]	train-auc:0.85046	test-auc:0.85564
# [220]	train-auc:0.85084	test-auc:0.85562
# [230]	train-auc:0.85114	test-auc:0.85564
# [240]	train-auc:0.85131	test-auc:0.85540
# [250]	train-auc:0.85165	test-auc:0.85525
# [260]	train-auc:0.85178	test-auc:0.85523
# [270]	train-auc:0.85219	test-auc:0.85533
# [280]	train-auc:0.85238	test-auc:0.85555
# [290]	train-auc:0.85252	test-auc:0.85565
# [300]	train-auc:0.85263	test-auc:0.85569
# [310]	train-auc:0.85276	test-auc:0.85565
# [320]	train-auc:0.85273	test-auc:0.85546
# [330]	train-auc:0.85311	test-auc:0.85537
# [340]	train-auc:0.85316	test-auc:0.85532
# [350]	train-auc:0.85340	test-auc:0.85503
# [360]	train-auc:0.85373	test-auc:0.85496
# [370]	train-auc:0.85408	test-auc:0.85518
# [378]	train-auc:0.85443	test-auc:0.85524
# Test Accuracy:  0.7178947368421053
# Buying 6 shares for 151.60. Remaining Balance: 90.40000000000009
# Selling all shares for 167.57, cash balance: $1095.8200000000002
# Buying 6 shares for 170.03. Remaining Balance: 75.6400000000001
# Selling all shares for 163.62, cash balance: $1057.3600000000001
# Buying 6 shares for 163.43. Remaining Balance: 76.78000000000009
# Selling all shares for 153.84, cash balance: $999.82
# Buying 6 shares for 156.90. Remaining Balance: 58.41999999999996
# Selling all shares for 150.43, cash balance: $961.0
# Buying 6 shares for 142.99. Remaining Balance: 103.05999999999995
# Selling all shares for 138.38, cash balance: $933.3399999999999
# Buying 6 shares for 142.41. Remaining Balance: 78.87999999999988
# Selling all shares for 144.80, cash balance: $947.68
# Buying 6 shares for 155.74. Remaining Balance: 13.239999999999895
# Selling all shares for 138.88, cash balance: $846.5199999999999
# Buying 5 shares for 146.87. Remaining Balance: 112.16999999999985
# Selling all shares for 148.11, cash balance: $852.7199999999999
# Buying 5 shares for 148.03. Remaining Balance: 112.56999999999994
# Selling all shares for 146.63, cash balance: $845.7199999999999
# Buying 5 shares for 144.49. Remaining Balance: 123.26999999999987
# Selling all shares for 143.21, cash balance: $839.3199999999999
# Buying 6 shares for 130.15. Remaining Balance: 58.419999999999845
# Selling all shares for 148.48, cash balance: $949.2999999999997
# Buying 6 shares for 151.03. Remaining Balance: 43.11999999999966
# Selling all shares for 162.03, cash balance: $1015.2999999999997
# Buying 6 shares for 165.56. Remaining Balance: 21.939999999999714
# Selling all shares for 165.79, cash balance: $1016.6799999999997
# Buying 5 shares for 173.57. Remaining Balance: 148.8299999999998
# Selling all shares for 188.61, cash balance: $1091.8799999999999
# Buying 5 shares for 193.99. Remaining Balance: 121.92999999999984
# Selling all shares for 191.17, cash balance: $1077.7799999999997
# Buying 5 shares for 181.12. Remaining Balance: 172.17999999999972
# Selling all shares for 177.56, cash balance: $1059.9799999999996
# Buying 6 shares for 173.75. Remaining Balance: 17.479999999999563
# Selling all shares for 172.40, cash balance: $1051.8799999999997
# Buying 6 shares for 173.66. Remaining Balance: 9.919999999999618
# Selling all shares for 175.84, cash balance: $1064.9599999999996
# Buying 6 shares for 173.97. Remaining Balance: 21.139999999999645
# Selling all shares for 192.53, cash balance: $1176.3199999999997
# Buying 6 shares for 188.63. Remaining Balance: 44.539999999999736
# Selling all shares for 184.40, cash balance: $1150.9399999999998
# Buying 6 shares for 188.85. Remaining Balance: 17.839999999999918
# Selling all shares for 185.04, cash balance: $1128.08
# Buying 6 shares for 173.72. Remaining Balance: 85.75999999999999
# Selling all shares for 170.85, cash balance: $1110.86
# Buying 6 shares for 175.04. Remaining Balance: 60.61999999999989
# Selling all shares for 168.00, cash balance: $1068.62
# Buying 6 shares for 169.02. Remaining Balance: 54.49999999999977
# Selling all shares for 169.89, cash balance: $1073.8399999999997
# Buying 6 shares for 173.50. Remaining Balance: 32.83999999999969
# Selling all shares for 186.88, cash balance: $1154.1199999999997
# Buying 6 shares for 189.98. Remaining Balance: 14.239999999999782
# Selling all remaining held shares, cash balance: $1299.6799999999998 ***********************
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_iteration</td><td>▁</td></tr><tr><td>best_score</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test-auc</td><td>▁▁▁▁▂▂▃▆▇█▇███████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>train-auc</td><td>▁▁▁▁▂▂▂▃▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Buy And Hold (Base ROI)</td><td>62.64</td></tr><tr><td>Max ROI</td><td>2121.475</td></tr><tr><td>ROI</td><td>299.68</td></tr><tr><td>accuracy</td><td>0.71789</td></tr><tr><td>best_iteration</td><td>178</td></tr><tr><td>best_score</td><td>0.85731</td></tr><tr><td>epoch</td><td>378</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">XGBoostClassNative_shuffled_1721697624</strong> at: <a href='https://wandb.ai/christopherandrews/StockPredictor/runs/dxo9gfxd' target="_blank">https://wandb.ai/christopherandrews/StockPredictor/runs/dxo9gfxd</a><br/> View project at: <a href='https://wandb.ai/christopherandrews/StockPredictor' target="_blank">https://wandb.ai/christopherandrews/StockPredictor</a><br/>Synced 5 W&B file(s), 2 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240722_192024-dxo9gfxd/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test_xgb, y_pred_test_xgb), annot=True, fmt="d")
# Out:
# <Axes: >

# %% [markdown]
# ### show the tree

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 28,12
xgb.plot_tree(cls2)
plt.show()

# %%
from xgboost import plot_importance

fig, ax = plt.subplots(figsize=(9,5))
plot_importance(cls2, ax=ax, importance_type="gain")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test_xgb, y_pred), annot=True, fmt="d")
# Out:
# <Axes: >

# %%
stockutils.plot_feature_importances(X_train=X_train, estimator=xgb_gs.best_estimator_)

# %% [markdown]
# XGBoost also has an equivalent feature importance graph

# %%
xgb.plot_importance(xgb_gs.best_estimator_, importance_type="gain")
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgb.plot_importance(xgb_gs.best_estimator_)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# # How do these models perform on the stock market?
#
# This won't be quite accurate, (we should use a different stock, or timeframe perhaps) but lets run the model predictions on the full dataset, plot the buys and sells, and then calculate our return

# %%
#plop the target value into the otherdf for plotting
otherdf['Target'] = targetdf['Target']

otherdf
# Out:
#               close    vix  2yr_Yield  10yr_Yield Target
# date
# 1/13/2015   27.5550  20.56      0.541       1.905   HOLD
# 1/14/2015   27.4500  21.48      0.501       1.855   HOLD
# 1/15/2015   26.7050  22.39      0.420       1.728   HOLD
# 1/16/2015   26.4975  20.95      0.488       1.831   HOLD
# 1/20/2015   27.1800  19.89      0.499       1.791    BUY
# ...             ...    ...        ...         ...    ...
# 6/7/2024   196.8900  12.22      4.889       4.433    BUY
# 6/10/2024  193.1200  12.74      4.885       4.471    BUY
# 6/11/2024  207.1500  12.85      4.834       4.402    BUY
# 6/12/2024  213.0700  12.04      4.756       4.318    BUY
# 6/13/2024  214.2400  11.94      4.703       4.248    BUY
#
# [2371 rows x 5 columns]

# %%
# gather full predictions on the whole dataset
dtc_y_full_pred = dtc_gs.predict(stockdf)
adb_y_full_pred = adb_gs.predict(stockdf)
gbc_y_full_pred = gbc_gs.predict(stockdf)
rf_y_full_pred = rf_gs.predict(stockdf)

xgb_y_full_pred = xgb_gs.predict(stockdf)

#next, our calculate_total_gains requires a dataframe with date index, and 'close' and 'Target' features.


y_full_xgb = pd.Categorical(y_orig).codes
full_xgb = xgb.DMatrix(stockdf, y_full_xgb, enable_categorical=True)
xgb_native_y_full_pred = cls2.predict(full_xgb)

# %%
#dtc_y_full_pred

# %%
#dtc_y_full_pred = dtc_gs.predict(stockdf)

# %%
dtc_predictions = targetdf.copy()
dtc_predictions['Target'] = dtc_y_full_pred
dtc_predictions['close'] = otherdf['close']

adb_predictions = targetdf.copy()
adb_predictions['Target'] = adb_y_full_pred
adb_predictions['close'] = otherdf['close']

gbc_predictions = targetdf.copy()
gbc_predictions['Target'] = gbc_y_full_pred
gbc_predictions['close'] = otherdf['close']

rf_predictions = targetdf.copy()
rf_predictions['Target'] = rf_y_full_pred
rf_predictions['close'] = otherdf['close']

xgb_predictions = targetdf.copy()
xgb_predictions['Target'] = xgb_y_full_pred
xgb_predictions['close'] = otherdf['close']

xgb_native_predictions = targetdf.copy()
xgb_native_predictions['Target'] = xgb_native_y_full_pred
xgb_native_predictions['close'] = otherdf['close']

# %%
import math

def calculate_total_gains(df, init_value, init_price, transaction_cost_fixed=0.0  ):
    price = init_price
    num_shares_owned = 0
    gain = 0.0
    cash_balance = init_value
    for idx, row in df.iterrows():
        price = df.loc[idx,'close']#price + (price * row['price_change_pct'])
        if row["Target"] == 'BUY' or row['Target'] == 0:
            max_shares = math.floor(cash_balance/price)
            if max_shares > 0:
                num_shares_owned += max_shares
                cash_balance = cash_balance - (max_shares*price)
                print("Buying {} shares for {:0.2f}. Remaining Balance: {}".format(max_shares, price, cash_balance))
        elif row["Target"] == 'SELL' or row['Target']== 2:
            cash_balance = cash_balance + (num_shares_owned * price)
            if num_shares_owned != 0:
                print("Selling all shares for {:0.2f}, cash balance: ${}".format(price, cash_balance))
            num_shares_owned = 0
    #sell at the end for gain calculation if we are holding stock
    cash_balance = cash_balance + (num_shares_owned * price)   
    print("Selling all remaining held shares, cash balance: ${} ***********************".format(cash_balance))
    roi = cash_balance - init_value
    return roi

# %%
initial_investment = 1000

# %% [markdown]
# ### Buy and Hold

# %%
# Buy and hold performance
# Selling all shares for 185.64, cash balance: $6899.429999999997
# Buying 36 shares for 188.63. Remaining Balance: 108.74999999999636
# Selling all shares for 170.12, cash balance: $6233.069999999996
# Buying 35 shares for 173.72. Remaining Balance: 152.86999999999625
# Selling all shares for 168.82, cash balance: $6061.569999999996
# Buying 34 shares for 175.04. Remaining Balance: 110.2099999999964
# Selling all remaining held shares, cash balance: $7394.369999999996 ***********************
# 6394.369999999996

# %% [markdown]
# Pretty poor ROI compared to perfect, and is worse than buy and hold

# %%
#test_full['price'] = X_test_orig['close'].to_numpy()
#pred_full['price'] = X_test_orig['close'].to_numpy()
#test_full.head()

a4_dims = (16,10)
fig, ax = plt.subplots(figsize=a4_dims)
#plot the actual close line
ax=sns.lineplot(data=otherdf, x=otherdf.index, y='close', c='black', alpha=0.4)
# plot the predicted values
sns.scatterplot(data=dtc_predictions, x=dtc_predictions.index, y='close', hue='Target',s=20)

#sns.scatterplot(data=otherdf, x=otherdf.index, y='close', hue='Target', size=0.1 )
# Out:
# <Axes: xlabel='date', ylabel='close'>

# %% [markdown]
# ### AdaBoost Performance

# %%
#AdaBoost Model
calculate_total_gains(adb_predictions, init_value=initial_investment, init_price=adb_predictions['close'][0])
# Out:
# Buying 36 shares for 27.39. Remaining Balance: 14.050000000000068
# Selling all shares for 31.13, cash balance: $1134.6400000000003
# Buying 35 shares for 32.12. Remaining Balance: 10.527500000000373
# Selling all shares for 30.64, cash balance: $1083.0150000000003
# Buying 34 shares for 31.40. Remaining Balance: 15.330000000000382
# Selling all shares for 30.69, cash balance: $1058.8750000000005
# Buying 36 shares for 29.12. Remaining Balance: 10.375000000000455
# Selling all shares for 26.44, cash balance: $962.2150000000005
# Buying 34 shares for 28.08. Remaining Balance: 7.580000000000496
# Selling all shares for 28.11, cash balance: $963.3200000000005
# Buying 34 shares for 27.95. Remaining Balance: 13.105000000000473
# Selling all shares for 29.03, cash balance: $1000.0400000000004
# Buying 33 shares for 29.72. Remaining Balance: 19.280000000000427
# Selling all shares for 28.30, cash balance: $953.0150000000004
# Buying 37 shares for 25.36. Remaining Balance: 14.88000000000045
# Selling all shares for 23.36, cash balance: $879.0150000000004
# Buying 36 shares for 24.09. Remaining Balance: 11.865000000000464
# Selling all shares for 23.50, cash balance: $858.0450000000004
# Buying 35 shares for 24.16. Remaining Balance: 12.445000000000391
# Selling all shares for 26.87, cash balance: $952.8950000000004
# Buying 40 shares for 23.47. Remaining Balance: 14.095000000000482
# Selling all shares for 24.34, cash balance: $987.4950000000006
# Buying 41 shares for 23.97. Remaining Balance: 4.622500000000514
# Selling all shares for 25.78, cash balance: $1061.7050000000004
# Buying 39 shares for 26.99. Remaining Balance: 9.192500000000337
# Selling all shares for 28.43, cash balance: $1117.9625000000003
# Buying 40 shares for 27.49. Remaining Balance: 18.46250000000032
# Selling all shares for 37.24, cash balance: $1508.2625000000003
# Buying 41 shares for 36.45. Remaining Balance: 13.6075000000003
# Selling all shares for 39.02, cash balance: $1613.3250000000003
# Buying 41 shares for 38.85. Remaining Balance: 20.577500000000327
# Selling all shares for 42.78, cash balance: $1774.4550000000004
# Buying 42 shares for 41.84. Remaining Balance: 17.07000000000039
# Selling all shares for 42.82, cash balance: $1815.4050000000004
# Buying 42 shares for 43.20. Remaining Balance: 1.0050000000003365
# Buying 36 shares for 142.99. Remaining Balance: 44.10830000000078
# Selling all shares for 138.38, cash balance: $5025.788300000001
# Buying 35 shares for 142.41. Remaining Balance: 41.43830000000162
# Selling all shares for 145.03, cash balance: $5117.488300000002
# Buying 34 shares for 146.87. Remaining Balance: 123.90830000000187
# Selling all shares for 144.22, cash balance: $5027.388300000001
# Buying 33 shares for 148.03. Remaining Balance: 142.39830000000165
# Selling all shares for 142.91, cash balance: $4858.428300000001
# Buying 33 shares for 144.49. Remaining Balance: 90.25830000000133
# Selling all shares for 136.50, cash balance: $4594.758300000001
# Buying 35 shares for 129.62. Remaining Balance: 58.05830000000151
# Selling all shares for 148.48, cash balance: $5254.858300000001
# Buying 34 shares for 151.03. Remaining Balance: 119.83830000000034
# Selling all shares for 160.10, cash balance: $5563.2383
# Buying 33 shares for 165.56. Remaining Balance: 99.75829999999951
# Selling all shares for 181.99, cash balance: $6105.4283
# Buying 34 shares for 177.23. Remaining Balance: 79.60829999999987
# Selling all shares for 177.56, cash balance: $6116.6483
# Buying 34 shares for 176.08. Remaining Balance: 129.92829999999958
# Selling all shares for 171.96, cash balance: $5976.5683
# Buying 34 shares for 173.75. Remaining Balance: 69.06829999999991
# Selling all shares for 172.40, cash balance: $5930.6683
# Buying 34 shares for 173.66. Remaining Balance: 26.228300000000672
# Selling all shares for 175.46, cash balance: $5991.868300000001
# Buying 34 shares for 173.97. Remaining Balance: 76.88830000000144
# Selling all shares for 185.64, cash balance: $6388.648300000001
# Buying 34 shares for 186.19. Remaining Balance: 58.18830000000071
# Selling all shares for 183.63, cash balance: $6301.608300000001
# Buying 33 shares for 188.63. Remaining Balance: 76.81830000000082
# Selling all shares for 188.04, cash balance: $6282.1383000000005
# Buying 33 shares for 189.30. Remaining Balance: 35.23829999999998
# Selling all shares for 185.04, cash balance: $6141.5583
# Buying 33 shares for 184.37. Remaining Balance: 57.348299999999654
# Selling all shares for 181.16, cash balance: $6035.628299999999
# Buying 33 shares for 182.63. Remaining Balance: 8.838299999999435
# Selling all shares for 175.10, cash balance: $5787.1383
# Buying 33 shares for 173.72. Remaining Balance: 54.3782999999994
# Selling all shares for 170.85, cash balance: $5692.4283
# Buying 32 shares for 173.31. Remaining Balance: 146.5082999999995
# Selling all shares for 168.84, cash balance: $5549.3883
# Buying 32 shares for 169.67. Remaining Balance: 119.94830000000002
# Selling all shares for 168.00, cash balance: $5495.9483
# Buying 32 shares for 166.90. Remaining Balance: 155.14829999999984
# Selling all remaining held shares, cash balance: $7010.8283 ***********************
# 6010.8283

# %%
a4_dims = (16,10)
fig, ax = plt.subplots(figsize=a4_dims)
#plot the actual close line
ax=sns.lineplot(data=otherdf, x=otherdf.index, y='close', c='black', alpha=0.4)
# plot the predicted values
sns.scatterplot(data=xgb_predictions, x=xgb_predictions.index, y='close', hue='Target',s=20)
# Out:
# <Axes: xlabel='date', ylabel='close'>

# %%
a4_dims = (16,10)
fig, ax = plt.subplots(figsize=a4_dims)
#plot the actual close line
ax=sns.lineplot(data=otherdf, x=otherdf.index, y='close', c='black', alpha=0.4)
# plot the predicted values
sns.scatterplot(data=xgb_native_predictions, x=xgb_native_predictions.index, y='close', hue='Target',s=20)
# Out:
# <Axes: xlabel='date', ylabel='close'>
